# %%
from sksurv import datasets
import numpy as np
import pandas as pd

# %%
features, outcome = datasets.load_veterans_lung_cancer()

# %%
features
# Out:
#      Age_in_years  Celltype  Karnofsky_score  Months_from_Diagnosis  \
# 0            69.0  squamous             60.0                    7.0
# 1            64.0  squamous             70.0                    5.0
# 2            38.0  squamous             60.0                    3.0
# 3            63.0  squamous             60.0                    9.0
# 4            65.0  squamous             70.0                   11.0
# ..            ...       ...              ...                    ...
# 132          65.0     large             75.0                    1.0
# 133          64.0     large             60.0                    5.0
# 134          67.0     large             70.0                   18.0
# 135          65.0     large             80.0                    4.0
# 136          37.0     large             30.0                    3.0
#
#     Prior_therapy Treatment
# 0              no  standard
# 1             yes  standard
# 2              no  standard
# 3             yes  standard
# ...

# %%
outcome
# Out:
# array([( True,  72.), ( True, 411.), ( True, 228.), ( True, 126.),
#        ( True, 118.), ( True,  10.), ( True,  82.), ( True, 110.),
#        ( True, 314.), (False, 100.), ( True,  42.), ( True,   8.),
#        ( True, 144.), (False,  25.), ( True,  11.), ( True,  30.),
#        ( True, 384.), ( True,   4.), ( True,  54.), ( True,  13.),
#        (False, 123.), (False,  97.), ( True, 153.), ( True,  59.),
#        ( True, 117.), ( True,  16.), ( True, 151.), ( True,  22.),
#        ( True,  56.), ( True,  21.), ( True,  18.), ( True, 139.),
#        ( True,  20.), ( True,  31.), ( True,  52.), ( True, 287.),
#        ( True,  18.), ( True,  51.), ( True, 122.), ( True,  27.),
#        ( True,  54.), ( True,   7.), ( True,  63.), ( True, 392.),
#        ( True,  10.), ( True,   8.), ( True,  92.), ( True,  35.),
#        ( True, 117.), ( True, 132.), ( True,  12.), ( True, 162.),
#        ( True,   3.), ( True,  95.), ( True, 177.), ( True, 162.),
# ...

# %%
# Introduce missing values
RATIO_MISSING = 0.1
num_records = len(features)
num_missing = round(RATIO_MISSING * num_records)
selection = np.random.choice(np.arange(num_records), size=num_missing, replace=False)
selection
# Out:
# array([ 48, 102,   9, 130,  59, 105, 126,  99,  87,   3, 123, 108,  71,
#         38])

# %%
features.loc[selection, "Age_in_years"] = np.nan
features.loc[selection, "Celltype"] = np.nan

# %%
features
# Out:
#      Age_in_years  Celltype  Karnofsky_score  Months_from_Diagnosis  \
# 0            69.0  squamous             60.0                    7.0
# 1            64.0  squamous             70.0                    5.0
# 2            38.0  squamous             60.0                    3.0
# 3             NaN       NaN             60.0                    9.0
# 4            65.0  squamous             70.0                   11.0
# ..            ...       ...              ...                    ...
# 132          65.0     large             75.0                    1.0
# 133          64.0     large             60.0                    5.0
# 134          67.0     large             70.0                   18.0
# 135          65.0     large             80.0                    4.0
# 136          37.0     large             30.0                    3.0
#
#     Prior_therapy Treatment
# 0              no  standard
# 1             yes  standard
# 2              no  standard
# 3             yes  standard
# ...

# %%
node1_df = features[features.columns[:3]]
node2_df = features[features.columns[3:]]

# %%
event_happened = [o[0] for o in outcome]
event_time = [o[1] for o in outcome]

outcome_df = pd.DataFrame({"event_time": event_time, "event_happened": event_happened})

outcome_df
# Out:
#      event_time  event_happened
# 0          72.0            True
# 1         411.0            True
# 2         228.0            True
# 3         126.0            True
# 4         118.0            True
# ..          ...             ...
# 132       133.0            True
# 133       111.0            True
# 134       231.0            True
# 135       378.0            True
# 136        49.0            True
#
# [137 rows x 2 columns]

# %%
from pathlib import Path

# %%
data_root = Path("data/impute_test")

# %%
node1_df.to_parquet(data_root/"node1.parquet")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 node1_df.to_parquet(data_root/"node1.parquet")
#
# File ~/projects/CARRIER/verticox/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/projects/CARRIER/verticox/venv/lib/python3.10/site-packages/pandas/core/frame.py:2976, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2889 """
#    2890 Write a DataFrame to the binary parquet format.
#    2891
#    (...)
#    2972 >>> content = f.read()
#    2973 """
#    2974 from pandas.io.parquet import to_parquet
# -> 2976 return to_parquet(
#    2977     self,
#    2978     path,
# ...

# %%
# %ls
# Out:
#  benchmark/                      Makefile                     scripts/
#  build/                          preprocess_data_1.parquet    source/
#  clear_tasks.py                  preprocess_data_2.parquet    test.log
#  create_benchmark_config.ipynb   preprocess_outcome.parquet   tests/
# 'Create custom v6 data.ipynb'    __pycache__/                 verticox/
#  generate_test_data.py           pyproject.toml
#  make.bat                        README.md
